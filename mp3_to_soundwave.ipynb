# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np

# %%
wave , sample_rate = librosa.load(path = '/Users/davidlindahl/Desktop/GitHub/singing_speech_NN-main/audio/files_for_spectrogramme/speech.wav')
plt.plot(wave)
plt.xticks([])
# Out:
# ([], [])
